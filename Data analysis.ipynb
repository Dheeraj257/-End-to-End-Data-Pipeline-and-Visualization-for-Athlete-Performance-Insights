# %%
# !pip install geopy
# Out:
# ...
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/125.4 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/125.4 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------  122.9/125.4 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# ...

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
from geopy.extra.rate_limiter import RateLimiter

# %%
df = pd.read_csv(r"C:\Users\DGV07\OneDrive\Desktop\ABROAD\CMU\Pandas\Pandas\ff_race_50.csv")

# %%
df
# Out:
#      Place     First          Last              City State  Age Division  \
# 0        1    Daniel        Wilson             Tulsa    OK   35        M
# 1        2      Eric         Davis         Greenwood    IN   38        M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43        M
# 3        4       Ron       Hammett         Montverde    FL   53        M
# 4        5      Seth          Cain            Geneva    FL   44        M
# ..     ...       ...           ...               ...   ...  ...      ...
# 104    105     David        Buning       Winter Park    FL   49        M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53        F
# 106    107      Chad          Ward         Woodstock    GA   39        M
# 107    108    Dennis     Stadelman            Cicero    NY   62        M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24        M
#
#          Time  Unnamed: 8  Unnamed: 9  Unnamed: 10
# ...

# %%
df2 = df.dropna(axis=1)

# %%
df2.head()
# Out:
#    Place    First     Last              City State  Age Division     Time
# 0      1   Daniel   Wilson             Tulsa    OK   35        M  8:23:01
# 1      2     Eric    Davis         Greenwood    IN   38        M  8:57:54
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43        M  9:24:35
# 3      4      Ron  Hammett         Montverde    FL   53        M  9:24:36
# 4      5     Seth     Cain            Geneva    FL   44        M  9:42:17

# %%
df2['Time'] = pd.to_timedelta(df2['Time'])
# Out:
# C:\Users\DGV07\AppData\Local\Temp\ipykernel_14756\2600047365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Time'] = pd.to_timedelta(df2['Time'])

# %%
df2['Total_Minutes'] = df2['Time'].dt.total_seconds()/60
# Out:
# C:\Users\DGV07\AppData\Local\Temp\ipykernel_14756\1718222051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Total_Minutes'] = df2['Time'].dt.total_seconds()/60

# %%
df2['Total_Minutes'] = df2['Total_Minutes'].round().astype(int)
# Out:
# C:\Users\DGV07\AppData\Local\Temp\ipykernel_14756\1089589449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Total_Minutes'] = df2['Total_Minutes'].round().astype(int)

# %%
df2
# Out:
#      Place     First          Last              City State  Age Division  \
# 0        1    Daniel        Wilson             Tulsa    OK   35        M
# 1        2      Eric         Davis         Greenwood    IN   38        M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43        M
# 3        4       Ron       Hammett         Montverde    FL   53        M
# 4        5      Seth          Cain            Geneva    FL   44        M
# ..     ...       ...           ...               ...   ...  ...      ...
# 104    105     David        Buning       Winter Park    FL   49        M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53        F
# 106    107      Chad          Ward         Woodstock    GA   39        M
# 107    108    Dennis     Stadelman            Cicero    NY   62        M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24        M
#
#                Time  Total_Minutes
# 0   0 days 08:23:01            503
# ...

# %%
df2.rename(columns = {'Division':'Gender'}, inplace = True)
# Out:
# C:\Users\DGV07\AppData\Local\Temp\ipykernel_14756\1149164375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns = {'Division':'Gender'}, inplace = True)

# %%
df2
# Out:
#      Place     First          Last              City State  Age Gender  \
# 0        1    Daniel        Wilson             Tulsa    OK   35      M
# 1        2      Eric         Davis         Greenwood    IN   38      M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43      M
# 3        4       Ron       Hammett         Montverde    FL   53      M
# 4        5      Seth          Cain            Geneva    FL   44      M
# ..     ...       ...           ...               ...   ...  ...    ...
# 104    105     David        Buning       Winter Park    FL   49      M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53      F
# 106    107      Chad          Ward         Woodstock    GA   39      M
# 107    108    Dennis     Stadelman            Cicero    NY   62      M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24      M
#
#                Time  Total_Minutes
# 0   0 days 08:23:01            503
# 1   0 days 08:57:54            538
# ...

# %%
def lat_long(city, state):
    address = f"{city}, {state}"
    try:
        geolocator = Nominatim(user_agent="running", timeout=10)
        location = geolocator.geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except GeocoderTimedOut:
        return None, None

# %%
df2['latitude'], df2['longitude'] = zip(*df2.apply(lambda x: lat_long(x['City'], x['State']),axis=1))
# Out:
# C:\Users\DGV07\AppData\Local\Temp\ipykernel_14756\3850022769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['latitude'], df2['longitude'] = zip(*df2.apply(lambda x: lat_long(x['City'], x['State']),axis=1))

# %%
df2['latlong'] = df2['latitude'].astype('str') + ', ' + df2['longitude'].astype('str')

# %%
df2
# Out:
#      Place     First          Last              City State  Age Gender  \
# 0        1    Daniel        Wilson             Tulsa    OK   35      M
# 1        2      Eric         Davis         Greenwood    IN   38      M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43      M
# 3        4       Ron       Hammett         Montverde    FL   53      M
# 4        5      Seth          Cain            Geneva    FL   44      M
# ..     ...       ...           ...               ...   ...  ...    ...
# 104    105     David        Buning       Winter Park    FL   49      M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53      F
# 106    107      Chad          Ward         Woodstock    GA   39      M
# 107    108    Dennis     Stadelman            Cicero    NY   62      M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24      M
#
#                Time  Total_Minutes   latitude  longitude  \
# ...

# %%
df2.to_csv(r'C:\Users\DGV07\OneDrive\Desktop\ABROAD\CMU\Pandas\Pandas\Ultracleanedupdata_output.csv', index=False)

# %%
df2['fullname'] = df2['First'] + ' ' + df2['Last']

# %%
df2
# Out:
#      Place     First          Last              City State  Age Gender  \
# 0        1    Daniel        Wilson             Tulsa    OK   35      M
# 1        2      Eric         Davis         Greenwood    IN   38      M
# 2        3   Stewart       Edwards  New Smyrna Beach    FL   43      M
# 3        4       Ron       Hammett         Montverde    FL   53      M
# 4        5      Seth          Cain            Geneva    FL   44      M
# ..     ...       ...           ...               ...   ...  ...    ...
# 104    105     David        Buning       Winter Park    FL   49      M
# 105    106     Kelly  Stoner Baker         Woodstock    GA   53      F
# 106    107      Chad          Ward         Woodstock    GA   39      M
# 107    108    Dennis     Stadelman            Cicero    NY   62      M
# 108    109  Jonathan       Burnham        Fort Moore    GA   24      M
#
#                Time  Total_Minutes   latitude  longitude  \
# ...
